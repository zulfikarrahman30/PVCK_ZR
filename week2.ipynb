# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfikarrahman30/PVCK_ZR/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('img5')

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello' ,org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
verticesvertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 uintuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili RGB
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
plt.imshow(img_gray, cmap=('RdYlGn'))

# %%
plt.imshow(img_gray, cmap=('GnBu'))

# %%
img_2 = img[10:100,10:100]
plt.imshow(img_2)

# %%
plt.imshow(img[5:30])

# %%
img_pussy = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_pussy, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_pussy, pt1=(900,100), pt2=(700,200), color=(0,255,0),thickness=10)
cv.rectangle(img_pussy, pt1=(400,400), pt2=(900,300), color=(255,255,255),thickness=10)
cv.rectangle(img_pussy, pt1=(100,900), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_pussy, pt1=(900,700), pt2=(600,550), color=(0,0,255),thickness=10)
plt.imshow(img_pussy)

# %%
img_z = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_z)

# %%
img_f = cv.imread('/content/drive/MyDrive/kitten01.jpg')
plt.imshow(img_f)

# %%
cv.rectangle(img_f,pt1=(260,160),pt2=(500,350),color=(0,0,255),thickness=15)
plt.imshow(img_f)

# %%
cv.circle(img_f,center=(380,260),radius=80,color=(255,0,0),thickness=8)
plt.imshow(img_f)

# %%
img_c = cv.imread('/content/drive/MyDrive/1501751648259.jpg')
plt.imshow(img_c)

# %%
img_rgb = cv.cvtColor(img_c,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(100,700),pt2=(10,800),color=(0,400,0),thickness=10)
plt.imshow(img_rgb)

# %%
font = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(img_rgb,text='Ini foto teman saya',org=(30,350),fontFace=font,fontScale=2,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img_rgb)
